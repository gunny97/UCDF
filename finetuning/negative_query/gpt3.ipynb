# %%
from evaluate import load

f1_metric = load('f1')
acc_metric = load('accuracy')
rec_metric = load('recall')
prec_metric = load('precision')

# %%
import pandas as pd
import os
import openai

openai.api_key = "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"

restart_sequence = "\n"

def gpt3_clf_fewshot(prompt):
  response = openai.Completion.create(
    model="text-davinci-002",
    prompt=f"Is the following text related to Judaism, Christianity, or Islam? \
            Answer yes or no. \
            \n'Judaism is the world’s oldest monotheistic religion, dating back nearly 4,000 years.': yes\n'Christianity is the most widely practiced religion in the world, with more than 2 billion followers.': yes\n'Islam is the second largest religion in the world after Christianity, with about 1.8 billion Muslims worldwide.': yes\n \
            \n'Buddhism is a faith that was founded by Siddhartha Gautama (“the Buddha”) more than 2,500 years ago in India.': No\n'Hinduism is the world’s oldest religion, according to many scholars, with roots and customs dating back more than 4,000 years.': No\n \
            \n\n\n\"{prompt} \"",
    temperature=0,
    max_tokens=6,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
  )
  return response['choices'][0]['text']

def gpt3_clf_fewshot_only_pos(prompt):
  response = openai.Completion.create(
    model="text-davinci-002",
    prompt=f"Is the following text related to Judaism, Christianity, or Islam? \
            Answer yes or no. \
            \n'Judaism is the world’s oldest monotheistic religion, dating back nearly 4,000 years.': yes\n'Christianity is the most widely practiced religion in the world, with more than 2 billion followers.': yes\n'Islam is the second largest religion in the world after Christianity, with about 1.8 billion Muslims worldwide.': yes\n \
            \n\n\n\"{prompt} \"",
    temperature=0,
    max_tokens=6,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
  )
  return response['choices'][0]['text']

def gpt3_clf_zeroshot(prompt):
  response = openai.Completion.create(
    model="text-davinci-002",
    prompt=f"Is the following text related to Judaism, Christianity, or Islam? \
            Answer yes or no. \
            \n\n\n\"{prompt} \"",
    temperature=0,
    max_tokens=6,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
  )
  return response['choices'][0]['text']

# %%
# korea
def gpt3_clf_zeroshot(prompt):
  # \n'South Korea': yes\n'K-pop': yes\n'Kimchi': yes\n'Seoul': yes \
  # \n'North Korea': No\n'Japan': No\n'Kimchi': yes\n'China': No \
  response = openai.Completion.create(
    model="text-davinci-002",
    prompt=f"Is the following text related to South Korea? \
            Answer yes or no. \
            \n\n\n\"{prompt}\"",
    temperature=0,
    max_tokens=6,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
  )
  return response['choices'][0]['text']

def gpt3_clf_fewshot_only_pos(prompt):
  # \n'South Korea': yes\n'K-pop': yes\n'Kimchi': yes\n'Seoul': yes \
  # \n'North Korea': No\n'Japan': No\n'Kimchi': yes\n'China': No \
  response = openai.Completion.create(
    model="text-davinci-002",
    prompt=f"Is the following text related to South Korea? \
            Answer yes or no. \
            \n'South Korea': yes\n'K-pop': yes\n'Kimchi': yes\n'Seoul': yes \
            \n\n\n\"{prompt}\"",
    temperature=0,
    max_tokens=6,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
  )
  return response['choices'][0]['text']

def gpt3_clf_fewshot(prompt):
  # \n'South Korea': yes\n'K-pop': yes\n'Kimchi': yes\n'Seoul': yes \
  # \n'North Korea': No\n'Japan': No\n'Kimchi': yes\n'China': No \
  response = openai.Completion.create(
    model="text-davinci-002",
    prompt=f"Is the following text related to South Korea? \
            Answer yes or no. \
            \n'South Korea': yes\n'K-pop': yes\n'Kimchi': yes\n'Seoul': yes \
            \n'North Korea': No\n'Japan': No\n'Kimchi': yes\n'China': No \
            \n\n\n\"{prompt}\"",
    temperature=0,
    max_tokens=6,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
  )
  return response['choices'][0]['text']

# %%
judaism_text = [
    # text from https://www.history.com/topics/religion/judaism
    ["Followers of Judaism believe in one God who revealed himself through ancient prophets.",1],
    ["Jewish people believe there’s only one God who has established a covenant—or special agreement—with them.",1],
    ["Their God communicates to believers through prophets and rewards good deeds while also punishing evil.",1],
    ["Most Jews (with the exception of a few groups) believe that their Messiah hasn’t yet come—but will one day.",1],
    ["Jewish people worship in holy places known as synagogues, and their spiritual leaders are called rabbis. ",1],
    ["The six-pointed Star of David is the symbol of Judaism.",1],
    ["Today, there are about 14 million Jews worldwide. Most of them live in the United States and Israel.",1],
    ["The Jewish sacred text is called the Tanakh or the “Hebrew Bible.”",1],
    ["It includes the same books as the Old Testament in the Christian Bible, but they’re placed in a slightly different order.",1],
]

christian_text = [
    # text from https://www.history.com/topics/religion/history-of-christianity
    ["The Christian faith centers on beliefs regarding the birth, life, death and resurrection of Jesus Christ.",1],
    ["While it started with a small group of adherents, many historians regard the spread and adoption of Christianity throughout the world as one of the most successful spiritual missions in human history.",1],
    ["Christians are monotheistic, i.e., they believe there’s only one God, and he created the heavens and the earth. This divine Godhead consists of three parts: the father (God himself), the son (Jesus Christ) and the Holy Spirit.",1],
    ["The essence of Christianity revolves around the life, death and Christian beliefs on the resurrection of Jesus. Christians believe God sent his son Jesus, the messiah, to save the world.",1],
    ["Christians contend that Jesus will return to earth again in what’s known as the Second Coming.",1],
    ["The Holy Bible includes important scriptures that outline Jesus’s teachings, the lives and teachings of major prophets and disciples, and offer instructions for how Christians should live.",1],
    ["Both Christians and Jews follow the Old Testament of the Bible, but Christians also embrace the New Testament.",1],
    ["The most important Christian holidays are Christmas (which celebrates the birth of Jesus) and Easter (which commemorates the resurrection of Jesus).",1],
]

islam_text = [
    # text from https://www.history.com/topics/religion/islam
    ["Although its roots go back further, scholars typically date the creation of Islam to the 7th century, making it the youngest of the major world religions.",1],
    ["Islam started in Mecca, in modern-day Saudi Arabia, during the time of the prophet Muhammad’s life. ",1],
    ["The word “Islam” means “submission to the will of God.”",1],
    ["Followers of Islam are called Muslims.",1],
    ["Muslims are monotheistic and worship one, all-knowing God, who in Arabic is known as Allah.",1],
    ["Followers of Islam aim to live a life of complete submission to Allah. They believe that nothing can happen without Allah’s permission, but humans have free will.",1],
    ["Islam teaches that Allah’s word was revealed to the prophet Muhammad through the angel Gabriel.",1],
    ["Muslims believe several prophets were sent to teach Allah’s law. They respect some of the same prophets as Jews and Christians, including Abraham, Moses, Noah and Jesus. Muslims contend that Muhammad was the final prophet.",1],
    ["Mosques are places where Muslims worship.",1],
    ["Some important Islamic holy places include the Kaaba shrine in Mecca, the Al-Aqsa mosque in Jerusalem, and the Prophet Muhammad’s mosque in Medina.",1],
    ["The Quran (or Koran) is the major holy text of Islam. The Hadith is another important book. Muslims also revere some material found in the Judeo-Christian Bible.",1],
    ["Followers worship Allah by praying and reciting the Quran. They believe there will be a day of judgment, and life after death.",1],
    ["A central idea in Islam is “jihad,” which means “struggle.” While the term has been used negatively in mainstream culture, ",1],
    ["Muslims believe it refers to internal and external efforts to defend their faith. Although rare, this can include military jihad if a “just war” is needed.",1]
]

budd_text = [
    # text from https://www.history.com/topics/religion/buddhism
    ["With about 470 million followers, scholars consider Buddhism one of the major world religions.",1],
    ["Its practice has historically been most prominent in East and Southeast Asia, but its influence is growing in the West.",1],
    ["Followers of Buddhism don’t acknowledge a supreme god or deity. They instead focus on achieving enlightenment—a state of inner peace and wisdom. When followers reach this spiritual echelon, they’re said to have experienced nirvana.",1],
    ["The religion’s founder, Buddha, is considered an extraordinary being, but not a god. The word Buddha means “enlightened.”",1],
    ["The path to enlightenment is attained by utilizing morality, meditation and wisdom. Buddhists often meditate because they believe it helps awaken truth.",1],
    ["There are many philosophies and interpretations within Buddhism, making it a tolerant and evolving religion.",1],
    ["Some scholars don’t recognize Buddhism as an organized religion, but rather, a “way of life” or a “spiritual tradition.”",1],
    ["Buddhism encourages its people to avoid self-indulgence but also self-denial.",1],
    ["Buddha’s most important teachings, known as The Four Noble Truths, are essential to understanding the religion.",1],
    ["Buddhists embrace the concepts of karma (the law of cause and effect) and reincarnation (the continuous cycle of rebirth).",1],
    ["Followers of Buddhism can worship in temples or in their own homes.",1],
    ["Buddhist monks, or bhikkhus, follow a strict code of conduct, which includes celibacy.",1],
    ["There is no single Buddhist symbol, but a number of images have evolved that represent Buddhist beliefs, including the lotus flower, the eight-spoked dharma wheel, the Bodhi tree and the swastika. ",1]
]

hindu_text = [
    # text from https://www.history.com/topics/religion/hinduism
    ["today, with about 900 million followers, Hinduism is the third-largest religion behind Christianity and Islam.",1],
    ["Hinduism is unique in that it’s not a single religion but a compilation of many traditions and philosophies.",1],
    ["Hinduism embraces many religious ideas. For this reason, it’s sometimes referred to as a “way of life” or a “family of religions,” as opposed to a single, organized religion.",1],
    ["Most forms of Hinduism are henotheistic, which means they worship a single deity, known as “Brahman,” but still recognize other gods and goddesses. Followers believe there are multiple paths to reaching their god.",1],
    ["Hindus believe in the doctrines of samsara (the continuous cycle of life, death, and reincarnation) and karma (the universal law of cause and effect)",1],
    ["One of the key thoughts of Hinduism is “atman,” or the belief in soul. This philosophy holds that living creatures have a soul, and they’re all part of the supreme soul.",1],
    ["The goal is to achieve “moksha,” or salvation, which ends the cycle of rebirths to become part of the absolute soul.",1],
    ["One fundamental principle of the religion is the idea that people’s actions and thoughts directly determine their current life and future lives.",1],
    ["Hindus strive to achieve dharma, which is a code of living that emphasizes good conduct and morality.",1],
    ["Hindus revere all living creatures and consider the cow a sacred animal.",1],
    ["Food is an important part of life for Hindus. Most don’t eat beef or pork, and many are vegetarians.",1],
    ["Hinduism is closely related to other Indian religions, including Buddhism, Sikhism and Jainism.",1],
]

normal_negative = [
    ['FSD Beta 10.69.2 rolling out now. Please note that top priority is safety, so expect it to be overly cautious, especially around pedestrians.',0],
    ["Looks good to roll out to all Tesla owners with 10.12.2 (~100k cars)!",0],
    ["Tesla North America aiming for >50 same hour service", 0],
    ["Enter your destination & your Tesla will automatically include Supercharging stops in your route",0],
    ['It’s sad though, because they are both uncomfortably sweaty from pedaling the paddle wheel propulsion system. ',0],
    ['When two people who are dating both like one of my tweets, i like to picture them both laughing at it together while holding hands in a swan boat',0],
    ["Recently after more than 20 years as a Google account holder my YouTube channel was suspended without warning and without any reason given.",0],
    ['After 20 years or more of using YouTube, they locked me out of my YouTube and yt music account without any reason.',0],
    ['I used to call Yahoo my safe email. They pretty much ruined that experience for me by deleting all my emails they claim due inactivity on my emails when I saw them less than 2 months ago.',0],
    ['Comments section of Yahoo controlled by alt-reality biased moderators supporting lies harmful to the Nation.',0],
    ['Although, Facebook is a social media platform, but it is also being used for business purposes, so fake, hateful, and political publishing should be avoided to make this platform professionally sound.',0],
    ['There is no mechanism to publish some verified information on this platform.',0],
    ['There is a lot of advertisement on Facebook, which always irritates me.',0],
    ["Jordi Cruyff has signed his contract as FC Barcelona's new sporting director of football. He has already been serving in the role since July 1.",0],
    ["An FC Barcelona player from 1993 to 1996, he returned to the club last season as director of the international area of the football section and played a key role in the two most recent transfer windows as a member of the Sporting Commission.",0],
    ["Our main objective was to create less stress for applicants. We constantly consider changes to the admissions process which could improve the experience for applicants, and the reasons for this change became more apparent over the last application cycle. ",0],
    ["All prospective students will now be able to express their interest in attending Justice Amy Coney Barrett’s alma mater in the regular application’s “Why Notre Dame Law School?” statement.",0],
    ["Then an assistant professor at Seokyeong University in Seoul, Cho was considered a surprise pick, given her lack of political experience, although she had built a reputation for her knowledge of defence and national security issues.",0],
    ["But just three days into the job, Cho’s political career was over, her dream shattered by a scandal that briefly overshadowed the race for the leadership of one of Asia’s biggest economies.",0],
    ["The sudden collapse of the cryptocurrencies in May triggered losses in the billions of dollars among investors both large and small, and led South Korean authorities to issue an arrest warrant Wednesday for Kwon. ",0],
    ["The digital sector is still reverberating from the devastating financial losses and the company’s spectacular demise that have turned the 30-year-old crypto entrepreneur into arguably the most hated man in South Korea. Adding to the scandal is the fact that Kwon has become a fugitive.",0],
    ["Understanding why so many took a gamble on Kwon has a lot to do with the power of social media – he managed to attract a vast network of followers. He was almost like the financial guru of a cult, said Donghwan Kim, a South Korean investment adviser in an interview with the Financial Times. ",0]
]

# %%
judaism = pd.DataFrame(judaism_text, columns = ['text','label'])
christian = pd.DataFrame(christian_text, columns = ['text','label'])
islam = pd.DataFrame(islam_text, columns = ['text','label'])
budd = pd.DataFrame(budd_text, columns = ['text','label'])
hindu = pd.DataFrame(hindu_text, columns = ['text','label'])


hard_negative = pd.concat([budd,hindu],axis=0)
normal_negative = pd.DataFrame(normal_negative, columns = ['text','label'])
hard_negative['label'] = 0
normal_negative['label'] = 0


positive = pd.concat([judaism, christian, islam],axis=0)
positive['label'] = 1

appendix_df = pd.concat([positive, hard_negative, normal_negative],axis=0)

# %%
appendix_df
# Out:
#                                                  text  label
# 0   Followers of Judaism believe in one God who re...      1
# 1   Jewish people believe there’s only one God who...      1
# 2   Their God communicates to believers through pr...      1
# 3   Most Jews (with the exception of a few groups)...      1
# 4   Jewish people worship in holy places known as ...      1
# ..                                                ...    ...
# 17  Then an assistant professor at Seokyeong Unive...      0
# 18  But just three days into the job, Cho’s politi...      0
# 19  The sudden collapse of the cryptocurrencies in...      0
# 20  The digital sector is still reverberating from...      0
# 21  Understanding why so many took a gamble on Kwo...      0
#
# [78 rows x 2 columns]

# %%
gpt3_pred_zeroshot = []
for text in appendix_df['text']:
    resp = gpt3_clf_zeroshot(text).lower()
    if 'yes' in resp:
        gpt3_pred_zeroshot.append(1)
    else:
        gpt3_pred_zeroshot.append(0)

# %%
f1_score = f1_metric.compute(predictions=gpt3_pred_zeroshot, references=appendix_df['label'])
acc_score = acc_metric.compute(predictions=gpt3_pred_zeroshot, references=appendix_df['label'])
rec_score = rec_metric.compute(predictions=gpt3_pred_zeroshot, references=appendix_df['label'])
prec_score = prec_metric.compute(predictions=gpt3_pred_zeroshot, references=appendix_df['label'])

print("zero_shot results")
print(f1_score)
print(acc_score)
print(rec_score)
print(prec_score)
# Out:
# zero_shot results
# {'f1': 1.0}
# {'accuracy': 1.0}
# {'recall': 1.0}
# {'precision': 1.0}

# %%
gpt3_pred_fewshot = []
for text in appendix_df['text']:
    resp = gpt3_clf_fewshot(text).lower()
    if 'yes' in resp:
        gpt3_pred_fewshot.append(1)
    else:
        gpt3_pred_fewshot.append(0)

# %%
f1_score = f1_metric.compute(predictions=gpt3_pred_fewshot, references=appendix_df['label'])
acc_score = acc_metric.compute(predictions=gpt3_pred_fewshot, references=appendix_df['label'])
rec_score = rec_metric.compute(predictions=gpt3_pred_fewshot, references=appendix_df['label'])
prec_score = prec_metric.compute(predictions=gpt3_pred_fewshot, references=appendix_df['label'])

print("few_shot results with pos+neg")
print(f1_score)
print(acc_score)
print(rec_score)
print(prec_score)
# Out:
# few_shot results with pos+neg
# {'f1': 0.9491525423728813}
# {'accuracy': 0.9615384615384616}
# {'recall': 0.9032258064516129}
# {'precision': 1.0}

# %%
gpt3_pred_fewshot_onlypos = []
for text in appendix_df['text']:
    resp = gpt3_clf_fewshot_only_pos(text).lower()
    if 'yes' in resp:
        gpt3_pred_fewshot_onlypos.append(1)
    else:
        gpt3_pred_fewshot_onlypos.append(0)

# %%
f1_score = f1_metric.compute(predictions=gpt3_pred_fewshot_onlypos, references=appendix_df['label'])
acc_score = acc_metric.compute(predictions=gpt3_pred_fewshot_onlypos, references=appendix_df['label'])
rec_score = rec_metric.compute(predictions=gpt3_pred_fewshot, references=appendix_df['label'])
prec_score = prec_metric.compute(predictions=gpt3_pred_fewshot_onlypos, references=appendix_df['label'])

print("few_shot results only pos")
print(f1_score)
print(acc_score)
print(rec_score)
print(prec_score)
# Out:
# few_shot results only pos
# {'f1': 0.9310344827586207}
# {'accuracy': 0.9487179487179487}
# {'recall': 0.9032258064516129}
# {'precision': 1.0}

# %% [markdown]
# ## korea

# %%
korean_text = [
    # https://facts.net/south-korea-facts/
    ["Although it might sound strange, dreaming about pigs is said to bring good fortune in Korea. In early Korea, pigs symbolized money and wealth.",1],
    ["The Seoul Capital Area houses over half of the population of South Korea.",1],
    ["Also known as Sudogwon, the Seoul Capital Area refers to South Korea’s metropolitan region of Seoul, Incheon, and Gyeonggi-do. ",1],
    ["SoKor harvests over 90% of the seaweed consumed around the world.",1],
    ["Parasite was the film to be nominated for the Oscars.",1],
    ["Bong Joon Ho’s Parasite made history for bagging 3 awards at the 2020 Oscars, which was the most of any film nominated.",1],
    ["Cheju, North Chŏlla, South Chŏlla, North Ch’ungch’ŏng, South Ch’ungch’ŏng, Kangwŏn, Kyŏnggi, North Kyŏngsang, and South Kyŏngsang.",1],
    [" Its 3-year-long war in the 1950s was followed by a ceasefire signed between North and South Korea.",1],
    ["The Cheomseongdae Observatory was built at Gyeongju in the mid-600s.",1],
    ["In 2012, the first robotic prison guards in the world were utilized in Pohang",1],
    ["The Shinsegae Department Store has been standing in Centum City, Busan since 2009.",1],
    ["Jinro Soju has been the best-selling liquor in the world for 11 consecutive years.",1],
    ["Hyundai KIA is the 5th largest automaker in the world and 2nd largest in Asia.",1],
    ["South Koreans have the highest estimated IQ in the whole world.",1],
    ["Other common family names in the country are Lee, also spelled Ree or Yi, and Park that is also spelled as Pak.",1],
    ["In Jeju Island, it is traditional for women to go to work while the husbands stay home.",1],
    ["An estimated 1 out of 3-5 women in the country have already undergone at least 1 cosmetic procedure.",1],
    ["Figure skater Yuna Kim was the first Korean winner of any Olympic figure skating discipline.",1],
    ["Hangul classifies as one of the Altaic languages, is affiliated to Japanese, and  contains some Chinese loanwords.",1],
    ["Hangul has phonetic symbols for 10 vowels and 14 consonants. ",1],
    ["Hallyu refers to the wave of popular culture",1],
    ["You may be familiar with it from the sudden surge in popularity of Korean cooking, K-pop, K-drama, and Korean streetwear.",1],
    ["Western influences have changed how the hanbok looks, but it remains the traditional dress for the country. ",1],
    ["Also known as ‘Meeting’ or ‘Sogaeting,’ these gatherings are an avenue for young university students to meet over drinks and meals.",1],
    ["The ‘ondol’ or warm stone generates heat through pipes beneath the flooring. ",1],
    ["Eyelid surgery is the most common cosmetic procedure done in Korea.",1],
    ["Aside from the usual staples like rice, soup or stew, South Koreans love side dishes.",1],
    ["Jjajangmyeon is a black-bean sauce noodle, while bulgogi is marinated meat that must be grilled over charcoal.",1],
    ["it is best to eat octopus raw.",1],
    ["The annual Kimjang festival takes place in Gwangju, a city in the southwest region of the country.",1],
    ["Over 20 million residents travel to their hometowns annually for the Harvest Moon Festival.",1],
    ["For 10 days of the event, mud massages, mud marathons, mud wrestling contests, and mud photo contests are up for revelers to enjoy. Originally, it started in 1998 as a strategy to advertise mud cosmetics.",1],
    ["At Deulmusae, there is a penis-themed restaurant that features Jaji or penis statues lined up along the path to the restaurant.",1],
    ["In the 21st century, K-pop rose as an international phenomenon, becoming one of the country’s most visible cultural exports.",1],
    ["BTS was the first K-pop artist to reach #1 in the US Billboard 200 chart.",1],
    ["Moreover, the worldwide following of BTS earned the group numerous world records.",1],
    ["Hence, Hallyu has become an economic cultural asset that has brought revenue and tourists to the country’s economy",1],
    ["Traditionally, snacking on rice cakes or Korean hard taffy is said to help the person “stick” to what they learned and pass.",1],
    ["The national flower of South Korea is the Mugunghwa or Rose of Sharon.",1],
    ["Along its beaches, there are giant stone statues known as dol hareubang or old grandfather",1],

    # Son heung min https://www.theguardian.com/football/blog/2022/sep/20/south-korea-breathes-sigh-of-relief-after-son-heung-min-ends-silence
    ["Son Heung-min’s spectacular 13-minute hat-trick against Leicester on Saturday ended his eight-game barren run,",1],
    ["As those Tottenham matches came and went without a goal, the mood back in east Asia grew ever gloomier, becoming darkest just before the Seoul dawn last week when the forward was substituted in the 2-0 defeat against Sporting in Lisbon.",1],
    ["The last time the 30-year-old arrived at Incheon International Airport was in May when he held the Premier League golden boot aloft for adoring fans and excited photographers. ",1],

    # Samsung https://www.britannica.com/topic/Samsung-Electronics
    ["Samsung specializes in the production of a wide variety of consumer and industry electronics, including appliances, digital media devices, semiconductors, memory chips, and integrated systems.",1],
    ["Samsung was founded as a grocery trading store on March 1, 1938, by Lee Byung-Chull.",1],
    ["In March 2010 Samsung Group executives made Lee Kun-Hee the head of Samsung Electronics, the conglomerate’s largest division.",1],   

    # LG 
    [" LG is still one of the best-known smartphone manufacturers in the world.",1],
    ["They were the first company to make Korean radios, TVs, refrigerators, washing machines and air conditioners.",1],
    ["While LG is currently mostly known for its “Life’s Good” slogan, that is not the only catchphrase stuck to their name.",1],

    # lee se dol https://en.yna.co.kr/view/AEN20191127004800315
    [" South Korean Go master Lee Se-dol, who retired from professional Go competition last week after gaining worldwide fame in 2016 as the only human to defeat the artificial intelligence (AI) Go player AlphaGo, said his retirement was primarily motivated by the invincibility of AI Go programs.",1],
    ["AlphaGo, built by Google's DeepMind Technologies, won four of its five matches against Lee in March 2016, but Lee's sole win in Game 4 remains the only time a human has beaten the AI player.",1],
    ["The 36-year-old, who scored 18 victories in international competitions and 32 victories in domestic events, submitted his letter of retirement to the Korea Baduk Association (KBA), which oversees Go professionals in South Korea, on Nov. 19, terminating his legendary 24-year career",1],

    # Gangnam style https://pitchfork.com/thepitch/psys-gangnam-style-changed-pop-music-whether-you-like-it-or-not/#:~:text=Nudged%20along%20by%20the%20likes,and%20country%20music%20award%20shows.
    ["Released July 15, 2012, “Gangnam Style” immediately reached the top of South Korea’s music charts, as one would expect from PSY (real name Park Jae-sang), a rapper boasting nationwide success over the previous decade. ",1],
    ["“Gangnam Style,” however, looked and sounded nothing like the K-pop norm, its big EDM chorus poking fun at the upper-class Seoul neighborhood of Gangnam.",1],
    ["PSY’s goofy “horse dance” would become 2012’s most inescapable pop culture touchstone, one so ubiquitous that it reached the NFL and country music award shows.",1],
    ["“Gangnam Style” is the most successful song from Asia, ever. ",1],


]

hard_negative = [
    
    # North Korea https://facts.net/north-korea-facts/
    ["their local name is Choson or “Choson-minjujuui-inmin-koughwaguk“.",0],
    ["The greatest health threat in North Korea is hunger.",0],
    ["You can find the 20-meter statues of Kim Il-Sung and Kim Jong-Il at the Grand Monument on Mansu Hill in Pyongyang.",0],

    # Japan https://facts.net/japan-facts/
    ["Japanese convenience stores also carry a wide array of health drinks for a balanced diet.",0],
    ["In 2019, Yahoo Japan announced a partnership with Line to merge into a single company.",0],
    ["JR Pass is a special fare ticket that gives you unlimited access to all JR trains for a set amount of time.",0],
    ["Osaka Castle is one of the most popular tourist destinations",0],

    # China https://facts.net/china-facts/
    ["China has the biggest population of any country in the world.",0],
    ["The Forbidden City is a palace complex in central Beijing that houses the Palace Museum. ",0],
    ["China produces the most gold out of any country in the world.",0],
    ["The Huizhou Ancient Town is a famous historical and cultural city in southern Anhui Province with over 2000 years of history.",0],

    # Russia https://facts.net/russia-facts/
    ["Russians have two ways of calling themselves.",0],
    ["The size of Russia has led to a varied climate.",0],
    ["Saint Basil’s Cathedral remains as one of Russia’s most iconic buildings.",0],
    ["Russia finally became a world power under Peter the Great in the 18th century.",0],

    # USA https://facts.net/usa-facts/
    ["The USA Waged a War of Independence from Britain",0],
    ["Western Expansion Increased the Size of the USA",0],
    ["There Are Over 900,000 Black Bears in the USA, but Not All of Them Are Black",0],
    ["It’s hard to discuss USA facts without mentioning the American movie industry. ",0],

    # Canada https://facts.net/canada-facts/
    ["More than 70% of Canada's population has European origins.",0],
    ["Also known as the Maple Leaf Flag, the Canadian flag has two main colors of red and white.",0],
    ["Canada's indigenous people used maple sap as a food staple.",0],
    ["Coming from the French word ‘Fete du Dominion,’ Canada Day used to be called Dominion day until the Canada Act’s passing in 1982.",0],

    # Egypt https://facts.net/egypt-facts/
    ["Egypt is one of the driest places on Earth",0],
    ["The Ancient Egyptians divided their land into the black earth and the red earth.",0],
    ["Slaves didn’t build the pyramids in Egypt.",0],
    ["The original architect of the pyramids was a priest named Imhotep.",0],

    # Brazil https://facts.net/brazil-facts/
    ["Semi-nomadic tribes inhabited Brazil before the colonization.",0],
    ["Both Baianos (from Bahia, in the Northeast Region of Brazil), and Capixabas (from the neighboring state of Esprito Santo), claim to be the inventors of the dish, and both serve up equally delicious variants.",0],
    ["Brazil produces about a third of all the coffee in the whole world, and the production of coffee plays a big part in the country’s economy.",0],
    ["The Iguaçu National Park in Parana State, Brazil has a land area of 85,262.5 hectares with a length of around 420 kilometers.",0],

    # Germany https://facts.net/germany-facts/
    ["The colors on the German flag represents the different political parties.",0],
    ["The Black Forest in Germany is known for its picturesque villages.",0],
    ["Germany and the Netherlands have a long rivalry in national football.",0],
]

normal_negative = [
    ['FSD Beta 10.69.2 rolling out now. Please note that top priority is safety, so expect it to be overly cautious, especially around pedestrians.',0],
    ["Looks good to roll out to all Tesla owners with 10.12.2 (~100k cars)!",0],
    ["Tesla North America aiming for >50 same hour service", 0],
    ["Enter your destination & your Tesla will automatically include Supercharging stops in your route",0],
    ['It’s sad though, because they are both uncomfortably sweaty from pedaling the paddle wheel propulsion system. ',0],
    ['When two people who are dating both like one of my tweets, i like to picture them both laughing at it together while holding hands in a swan boat',0],
    ["Recently after more than 20 years as a Google account holder my YouTube channel was suspended without warning and without any reason given.",0],
    ['After 20 years or more of using YouTube, they locked me out of my YouTube and yt music account without any reason.',0],
    ['I used to call Yahoo my safe email. They pretty much ruined that experience for me by deleting all my emails they claim due inactivity on my emails when I saw them less than 2 months ago.',0],
    ['Comments section of Yahoo controlled by alt-reality biased moderators supporting lies harmful to the Nation.',0],
    ['Although, Facebook is a social media platform, but it is also being used for business purposes, so fake, hateful, and political publishing should be avoided to make this platform professionally sound.',0],
    ['There is no mechanism to publish some verified information on this platform.',0],
    ['There is a lot of advertisement on Facebook, which always irritates me.',0],
    ["Jordi Cruyff has signed his contract as FC Barcelona's new sporting director of football. He has already been serving in the role since July 1.",0],
    ["An FC Barcelona player from 1993 to 1996, he returned to the club last season as director of the international area of the football section and played a key role in the two most recent transfer windows as a member of the Sporting Commission.",0],
    ["Our main objective was to create less stress for applicants. We constantly consider changes to the admissions process which could improve the experience for applicants, and the reasons for this change became more apparent over the last application cycle. ",0],
    ["All prospective students will now be able to express their interest in attending Justice Amy Coney Barrett’s alma mater in the regular application’s “Why Notre Dame Law School?” statement.",0],
    ['In light of the current public health crisis, Justin Bieber announces his rescheduled 2021 World Tour dates below.',0],
    ['In June, the singer revealed he was suffering from facial paralysis, after a diagnosis of Ramsay Hunt syndrome.',0],
    ["So I'm going to take a break from touring right now. I'm going to be OK, but I need to take time to rest and get better.",0],
    ["Ramsay Hunt Syndrome cannot be passed from one person to another, but it is a complication from a transmissible disease called shingles.",0],
    ["The president successfully preserved the status quo for two decades. Suddenly, he’s turned into a destroyer.",0],
    #["Ukraine’s successful counterattack means that for the first time ever in Russian President Vladimir Putin’s 22 years in power, he has to deal with elites who disagree with him—on strategic decisions over Russia’s war in Ukraine and how the war may end.",0]
]

# %%
korea = pd.DataFrame(korean_text, columns = ['text','label'])

hard = pd.DataFrame(hard_negative, columns = ['text','label'])
normal = pd.DataFrame(normal_negative, columns = ['text','label'])

negative = pd.concat([hard, normal],axis=0)

appendix_df = pd.concat([korea,negative],axis=0)

# %%
gpt3_pred_zeroshot = []
for text in appendix_df['text']:
    resp = gpt3_clf_zeroshot(text).lower()
    if 'yes' in resp:
        gpt3_pred_zeroshot.append(1)
    else:
        gpt3_pred_zeroshot.append(0)

# %%
f1_score = f1_metric.compute(predictions=gpt3_pred_zeroshot, references=appendix_df['label'])
acc_score = acc_metric.compute(predictions=gpt3_pred_zeroshot, references=appendix_df['label'])
rec_score = rec_metric.compute(predictions=gpt3_pred_zeroshot, references=appendix_df['label'])
prec_score = prec_metric.compute(predictions=gpt3_pred_zeroshot, references=appendix_df['label'])

print("zero_shot results")
print(f1_score)
print(acc_score)
print(rec_score)
print(prec_score)
# Out:
# zero_shot results
# {'f1': 0.9380530973451328}
# {'accuracy': 0.9375}
# {'recall': 0.9464285714285714}
# {'precision': 0.9298245614035088}

# %%
gpt3_pred_fewshot = []
for text in appendix_df['text']:
    resp = gpt3_clf_fewshot(text).lower()
    if 'yes' in resp:
        gpt3_pred_fewshot.append(1)
    else:
        gpt3_pred_fewshot.append(0)

# %%
f1_score = f1_metric.compute(predictions=gpt3_pred_fewshot, references=appendix_df['label'])
acc_score = acc_metric.compute(predictions=gpt3_pred_fewshot, references=appendix_df['label'])
rec_score = rec_metric.compute(predictions=gpt3_pred_fewshot, references=appendix_df['label'])
prec_score = prec_metric.compute(predictions=gpt3_pred_fewshot, references=appendix_df['label'])

print("few_shot results with pos+neg")
print(f1_score)
print(acc_score)
print(rec_score)
print(prec_score)
# Out:
# few_shot results with pos+neg
# {'f1': 0.37681159420289856}
# {'accuracy': 0.6160714285714286}
# {'recall': 0.23214285714285715}
# {'precision': 1.0}

# %%
gpt3_pred_fewshot_onlypos = []
for text in appendix_df['text']:
    resp = gpt3_clf_fewshot_only_pos(text).lower()
    if 'yes' in resp:
        gpt3_pred_fewshot_onlypos.append(1)
    else:
        gpt3_pred_fewshot_onlypos.append(0)

# %%
f1_score = f1_metric.compute(predictions=gpt3_pred_fewshot_onlypos, references=appendix_df['label'])
acc_score = acc_metric.compute(predictions=gpt3_pred_fewshot_onlypos, references=appendix_df['label'])
rec_score = rec_metric.compute(predictions=gpt3_pred_fewshot, references=appendix_df['label'])
prec_score = prec_metric.compute(predictions=gpt3_pred_fewshot_onlypos, references=appendix_df['label'])

print("few_shot results only pos")
print(f1_score)
print(acc_score)
print(rec_score)
print(prec_score)
# Out:
# few_shot results only pos
# {'f1': 0.4444444444444445}
# {'accuracy': 0.6428571428571429}
# {'recall': 0.23214285714285715}
# {'precision': 1.0}
